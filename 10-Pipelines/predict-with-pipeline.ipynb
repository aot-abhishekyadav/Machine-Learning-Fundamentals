# %% [markdown]
# <a href="https://colab.research.google.com/github/aot-abhishekyadav/Machine-Learning-Fundamentals/blob/main/10-Pipelines/predict-with-pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pickle

pipe = pickle.load(open('/content/drive/MyDrive/models1/pipe.pkl', 'rb'))
# Out:
# Mounted at /content/drive

# %%
import numpy as np

# %%
# Assume user input
test_input2 = np.array([3, 'male', 31.0, 0, 0, 7.5, 'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
