# %% [markdown]
# <a href="https://colab.research.google.com/github/aot-abhishekyadav/Machine-Learning-Fundamentals/blob/main/04-Pandas/pandas-profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Titanic1.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sample(5) # sample hume 5 random value dataset mai sai utha kai deta hai
# Out:
#      PassengerId  Survived  Pclass                                    Name  \
# 199          200         0       2  Yrois, Miss. Henriette ("Mrs Harbeck")
# 841          842         0       2                Mudd, Mr. Thomas Charles
# 314          315         0       2                      Hart, Mr. Benjamin
# 429          430         1       3      Pickard, Mr. Berk (Berk Trembisky)
# 730          731         1       1           Allen, Miss. Elisabeth Walton
#
#         Sex   Age  SibSp  Parch             Ticket      Fare Cabin Embarked
# 199  female  24.0      0      0             248747   13.0000   NaN        S
# 841    male  16.0      0      0        S.O./P.P. 3   10.5000   NaN        S
# 314    male  43.0      1      1       F.C.C. 13529   26.2500   NaN        S
# 429    male  32.0      0      0  SOTON/O.Q. 392078    8.0500   E10        S
# 730  female  29.0      0      0              24160  211.3375    B5        S

# %%
# !pip install ydata-profiling
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 42.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 30.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 118.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 60.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.6 MB/s eta 0:00:00
# ...
# /tmp/ipykernel_501/3854134857.py:2: DeprecationWarning:
#     `import ydata_profiling` is deprecated and will not receive more updates.
#     Please install fg-data-profiling via `pip install fg-data-profiling` and use `import data_profiling` instead.
#
#   from ydata_profiling import ProfileReport
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import shutil
import os

# Define the destination path in your Google Drive
# Make sure the directory 'My Drive' is mounted and accessible
drive_path = '/content/drive/MyDrive/output.html'

# Move the generated output.html file to Google Drive
shutil.move('output.html', drive_path)

print(f'output.html saved to {drive_path}')
# Out:
# output.html saved to /content/drive/MyDrive/output.html

# %% [markdown]
# YData Profiling ek Python library hai jo kisi bhi dataset ki automatic EDA report generate karti hai. Isme missing values, correlations, distributions, outliers, duplicates aur statistical summary ek hi report mein mil jati hai, jisse data ko jaldi samajhne mein help milti hai.
#
# Kab use karna chahiye?
#
# ✔️ Naya dataset explore karte waqt
#
# ✔️ Kaggle competitions
#
# ✔️ ML projects
#
# ✔️ Data cleaning se pehle
#
# Note: Bahut bade datasets (lakhs ya millions of rows) par report generate karne mein kaafi time aur memory lag sakti hai.

# %% [markdown]
# Iska work kya hai?
#
# Ye automatically batata hai:
#
# 📊 Dataset ka shape (rows × columns)
#
# 📝 Data types (int, float, object, etc.)
#
# ❌ Missing values kitni hain
#
# 🔁 Duplicate rows
#
# 📈 Mean, Median, Min, Max, Std
#
# 📉 Percentiles (25%, 50%, 75%)
#
# 🔗 Correlation between features
#
# ⚠️ Outliers detect karta hai
#
# 🧩 Unique values aur value counts
#
# 📊 Distribution (Histogram)
#
# 📦 Boxplots
#
# 🧠 Memory usage
